# %%
import matplotsoccer as mps
import matplotlib.pyplot as plt

mps.field(show=False)
plt.savefig("../img/whitefield.png",bbox_inches="tight",padding=0)
plt.show()

mps.field("green",figsize=5,show=False)
plt.axis("on")
plt.savefig("../img/greenfield_axis.png",bbox_inches="tight",padding=0)
plt.show()
